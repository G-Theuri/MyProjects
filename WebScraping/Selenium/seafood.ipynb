# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
import tqdm.notebook as tqdm
import time
import pandas as pd
import json

# %%
driver = webdriver.Chrome()
driver.get('https://www.seafoodsource.com/supplier-directory')
time.sleep(20)

driver.find_element(By.XPATH, "//button[@id='onetrust-accept-btn-handler']").click()

# %%
data = []
nextbutton =True


while nextbutton:
    listings = driver.find_elements(By.XPATH, "//ol[@class='ais-Hits-list']/li")
    time.sleep(1)
    for listing in listings:
        driver.execute_script("arguments[0].scrollIntoView();", listing)
        time.sleep(2)

        link = listing.find_element(By.XPATH, ".//div[@class='results-btn-wrap']/a").get_attribute('href')
        page = driver.execute_script("window.open('{}', '_blank');".format(link))
        driver.switch_to.window(driver.window_handles[1])
        
        data.append({
            'webpage': (driver.find_element(By.XPATH,"//div[@class='t3p0-col col-sm-12']/div/a").get_attribute('href') if not None else None),
            'email': (driver.find_element(By.XPATH,"//div[@class='t3p0-col col-sm-12']/div[2]/a").get_attribute('href') if not None else None),
            'phone': (driver.find_element(By.XPATH,"//div[@class='t3p0-col col-sm-12']/div[3]").text if not None else None),
            'address': (driver.find_element(By.XPATH,"//div[@class='t3p0-row row supplier-directory__address']/div").text if not None else None),
            #'category': (driver.find_element(By.XPATH,"//div[@class='t3p0-col col-sm-8']/div[2]/ul/li").text if not None else None),
            'event': (driver.find_element(By.XPATH,"//div[@class='t3p0-col col-sm-8']/div[3]").text if not None else None),
            })
        


        time.sleep(1)
        driver.close()

        driver.switch_to.window(driver.window_handles[0])
        time.sleep(2)
    try:
        next_page = driver.find_element(By.XPATH,"//a[@aria-label='Next']").click()
    except:
        nextbutton=False

with open('seafood.json', 'w') as f:
    json.dump(data, f)

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[63], line 12
#       9 driver.execute_script("arguments[0].scrollIntoView();", listing)
#      10 time.sleep(2)
# ---> 12 link = listing.find_element(By.XPATH, ".//div[@class='results-btn-wrap']/a").get_attribute('href')
#      13 page = driver.execute_script("window.open('{}', '_blank');".format(link))
#      14 driver.switch_to.window(driver.window_handles[1])
#
# File c:\Users\ereez\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:417, in WebElement.find_element(self, by, value)
#     414     by = By.CSS_SELECTOR
#     415     value = f'[name="{value}"]'
# --> 417 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\ereez\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File c:\Users\ereez\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File c:\Users\ereez\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=126.0.6478.128); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#stale-element-reference-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7AD34EEB2+31554]
# 	(No symbol) [0x00007FF7AD2C7EE9]
# 	(No symbol) [0x00007FF7AD18872A]
# 	(No symbol) [0x00007FF7AD18E55E]
# 	(No symbol) [0x00007FF7AD190EB1]
# 	(No symbol) [0x00007FF7AD190F50]
# 	(No symbol) [0x00007FF7AD1D7F6C]
# 	(No symbol) [0x00007FF7AD1D853C]
# 	(No symbol) [0x00007FF7AD1CBBAC]
# 	(No symbol) [0x00007FF7AD1FD06F]
# 	(No symbol) [0x00007FF7AD1CBA76]
# 	(No symbol) [0x00007FF7AD1FD240]
# 	(No symbol) [0x00007FF7AD21C977]
# 	(No symbol) [0x00007FF7AD1FCDD3]
# 	(No symbol) [0x00007FF7AD1CA33B]
# 	(No symbol) [0x00007FF7AD1CAED1]
# 	GetHandleVerifier [0x00007FF7AD658B2D+3217341]
# 	GetHandleVerifier [0x00007FF7AD6A5AF3+3532675]
# 	GetHandleVerifier [0x00007FF7AD69B0F0+3489152]
# 	GetHandleVerifier [0x00007FF7AD3FE786+750614]
# 	(No symbol) [0x00007FF7AD2D376F]
# 	(No symbol) [0x00007FF7AD2CEB24]
# 	(No symbol) [0x00007FF7AD2CECB2]
# 	(No symbol) [0x00007FF7AD2BE17F]
# 	BaseThreadInitThunk [0x00007FFFFF5F7374+20]
# 	RtlUserThreadStart [0x00007FFFFFE3CC91+33]
